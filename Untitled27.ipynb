# %%
import pandas as pd

# %%
s= pd.Series([2,-1,3,5])
s
# Out:
# 0    2
# 1   -1
# 2    3
# 3    5
# dtype: int64

# %%
import numpy as np
np.exp(s)
# Out:
# 0      7.389056
# 1      0.367879
# 2     20.085537
# 3    148.413159
# dtype: float64

# %%
s + [1000,2000,3000,4000]
# Out:
# 0    1002
# 1    1999
# 2    3003
# 3    4005
# dtype: int64

# %%
s + 100
# Out:
# 0    102
# 1     99
# 2    103
# 3    105
# dtype: int64

# %%
s < 0
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
s > 0
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
s2 = pd.Series([45, 60, 32, 24], index=['jack', 'bob', 'charles', 'darwin'])

# %%
s2['jack']
# Out:
# 45

# %%
s2[2]
# Out:
# 32

# %%
s2.loc['charles']
# Out:
# 32

# %%
s2.iloc[3]
# Out:
# 24

# %%
s2.iloc[2:3]
# Out:
# charles    32
# dtype: int64

# %%
s2.iloc[0:3]
# Out:
# jack       45
# bob        60
# charles    32
# dtype: int64

# %%
surprise = pd.Series([2500, 2501, 2502, 2503])
surprise
# Out:
# 0    2500
# 1    2501
# 2    2502
# 3    2503
# dtype: int64

# %%
surprice_slice = surprise[2:]
surprice_slice
# Out:
# 2    2502
# 3    2503
# dtype: int64

# %%
surprice_slice.iloc[0]
# Out:
# 2502

# %%
weights = {'alice': 68, 'bob': 83, 'colin': 86, 'darwin': 68}
s3 = pd.Series(weights)
s3
# Out:
# alice     68
# bob       83
# colin     86
# darwin    68
# dtype: int64

# %%
s4 = pd.Series(weights, index = ['colin', 'alice'])
s4
# Out:
# colin    86
# alice    68
# dtype: int64

# %%
print(s2.keys())
print(s3.keys())

s2 + s3
# Out:
# Index(['jack', 'bob', 'charles', 'darwin'], dtype='object')
# Index(['alice', 'bob', 'colin', 'darwin'], dtype='object')
# alice        NaN
# bob        143.0
# charles      NaN
# colin        NaN
# darwin      92.0
# jack         NaN
# dtype: float64

# %%
s5 = pd.Series([1000,1000,1000,1000])
print('s2=', s2.values)
print('s5 =', s5.values)

s2 + s5
# Out:
# s2= [45 60 32 24]
# s5 = [1000 1000 1000 1000]
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# bob       NaN
# charles   NaN
# darwin    NaN
# jack      NaN
# dtype: float64

# %%
meaning = pd.Series(10, ['finger', 'olympic events', 'Bill of Rights'])
meaning
# Out:
# finger            10
# olympic events    10
# Bill of Rights    10
# dtype: int64

# %%
s6 = pd.Series([83, 68], index=['bob', 'alice'], name='weights')
s6
# Out:
# bob      83
# alice    68
# Name: weights, dtype: int64

# %%
import matplotlib.pyplot as plt
temperatures = [4.4,5.1,6.1,6.2,6.1,6.1,5.7,5.2,4.7,4.1,3.9,3.5]
s7 = pd.Series(temperatures, name='Temperature')
s7.plot()
plt.show()

# %%
dates = pd.date_range('2018/12/28 5:45', periods=12, freq='H')
dates
# Out:
# DatetimeIndex(['2018-12-28 05:45:00', '2018-12-28 06:45:00',
#                '2018-12-28 07:45:00', '2018-12-28 08:45:00',
#                '2018-12-28 09:45:00', '2018-12-28 10:45:00',
#                '2018-12-28 11:45:00', '2018-12-28 12:45:00',
#                '2018-12-28 13:45:00', '2018-12-28 14:45:00',
#                '2018-12-28 15:45:00', '2018-12-28 16:45:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
temp_series = pd.Series(temperatures, dates)
temp_series
# Out:
# 2018-12-28 05:45:00    4.4
# 2018-12-28 06:45:00    5.1
# 2018-12-28 07:45:00    6.1
# 2018-12-28 08:45:00    6.2
# 2018-12-28 09:45:00    6.1
# 2018-12-28 10:45:00    6.1
# 2018-12-28 11:45:00    5.7
# 2018-12-28 12:45:00    5.2
# 2018-12-28 13:45:00    4.7
# 2018-12-28 14:45:00    4.1
# 2018-12-28 15:45:00    3.9
# 2018-12-28 16:45:00    3.5
# Freq: H, dtype: float64

# %%
temp_series.plot(kind='bar')

plt.grid(True)
plt.show()

# %%
temp_series_freq_2H = temp_series.resample('2H')
temp_series_freq_2H

# %%
temp_series_freq_2H = temp_series_freq_2H.mean()

# %%
temp_series_freq_2H.plot(kind='bar')
plt.show()

# %%
temp_series_freq_2H = temp_series.resample('2H').min()
temp_series_freq_2H
# Out:
# 2018-12-28 04:00:00    4.4
# 2018-12-28 06:00:00    5.1
# 2018-12-28 08:00:00    6.1
# 2018-12-28 10:00:00    5.7
# 2018-12-28 12:00:00    4.7
# 2018-12-28 14:00:00    3.9
# 2018-12-28 16:00:00    3.5
# Freq: 2H, dtype: float64

# %%
temp_series_freq_2H = temp_series.resample('2H').apply(np.min)
temp_series_freq_2H
# Out:
# 2018-12-28 04:00:00    4.4
# 2018-12-28 06:00:00    5.1
# 2018-12-28 08:00:00    6.1
# 2018-12-28 10:00:00    5.7
# 2018-12-28 12:00:00    4.7
# 2018-12-28 14:00:00    3.9
# 2018-12-28 16:00:00    3.5
# Freq: 2H, dtype: float64

# %%
temp_series_freq_15min = temp_series.resample('15Min').mean()
temp_series_freq_15min.head(n=10)
# Out:
# 2018-12-28 05:45:00    4.4
# 2018-12-28 06:00:00    NaN
# 2018-12-28 06:15:00    NaN
# 2018-12-28 06:30:00    NaN
# 2018-12-28 06:45:00    5.1
# 2018-12-28 07:00:00    NaN
# 2018-12-28 07:15:00    NaN
# 2018-12-28 07:30:00    NaN
# 2018-12-28 07:45:00    6.1
# 2018-12-28 08:00:00    NaN
# Freq: 15T, dtype: float64

# %%
temp_series_freq_15min = temp_series.resample('15Min').interpolate(method='cubic')
temp_series_freq_15min.head(n=10)
# Out:
# 2018-12-28 05:45:00    4.400000
# 2018-12-28 06:00:00    4.452911
# 2018-12-28 06:15:00    4.605113
# 2018-12-28 06:30:00    4.829758
# 2018-12-28 06:45:00    5.100000
# 2018-12-28 07:00:00    5.388992
# 2018-12-28 07:15:00    5.669887
# 2018-12-28 07:30:00    5.915839
# 2018-12-28 07:45:00    6.100000
# 2018-12-28 08:00:00    6.203621
# Freq: 15T, dtype: float64

# %%
temp_series.plot(label='Period: 1 hour')
temp_series_freq_15min.plot(label='Period: 15 minutes')
plt.legend()
plt.show()

# %%
temp_series_ny = temp_series.tz_localize('America/New_York')
temp_series_ny
# Out:
# 2018-12-28 05:45:00-05:00    4.4
# 2018-12-28 06:45:00-05:00    5.1
# 2018-12-28 07:45:00-05:00    6.1
# 2018-12-28 08:45:00-05:00    6.2
# 2018-12-28 09:45:00-05:00    6.1
# 2018-12-28 10:45:00-05:00    6.1
# 2018-12-28 11:45:00-05:00    5.7
# 2018-12-28 12:45:00-05:00    5.2
# 2018-12-28 13:45:00-05:00    4.7
# 2018-12-28 14:45:00-05:00    4.1
# 2018-12-28 15:45:00-05:00    3.9
# 2018-12-28 16:45:00-05:00    3.5
# dtype: float64

# %%
temp_series_paris = temp_series_ny.tz_convert('Europe/Paris')
temp_series_paris
# Out:
# 2018-12-28 11:45:00+01:00    4.4
# 2018-12-28 12:45:00+01:00    5.1
# 2018-12-28 13:45:00+01:00    6.1
# 2018-12-28 14:45:00+01:00    6.2
# 2018-12-28 15:45:00+01:00    6.1
# 2018-12-28 16:45:00+01:00    6.1
# 2018-12-28 17:45:00+01:00    5.7
# 2018-12-28 18:45:00+01:00    5.2
# 2018-12-28 19:45:00+01:00    4.7
# 2018-12-28 20:45:00+01:00    4.1
# 2018-12-28 21:45:00+01:00    3.9
# 2018-12-28 22:45:00+01:00    3.5
# dtype: float64

# %%
temp_series_paris_naive = temp_series_paris.tz_localize(None)
temp_series_paris_naive
# Out:
# 2018-12-28 11:45:00    4.4
# 2018-12-28 12:45:00    5.1
# 2018-12-28 13:45:00    6.1
# 2018-12-28 14:45:00    6.2
# 2018-12-28 15:45:00    6.1
# 2018-12-28 16:45:00    6.1
# 2018-12-28 17:45:00    5.7
# 2018-12-28 18:45:00    5.2
# 2018-12-28 19:45:00    4.7
# 2018-12-28 20:45:00    4.1
# 2018-12-28 21:45:00    3.9
# 2018-12-28 22:45:00    3.5
# dtype: float64

# %%
try:
    temp_series_paris_naive.tz_localize("Europe/Paris")
except Exception as e:
    print(type(e))
    print(e)

# %%
temp_series_paris_naive.tz_localize('Europe/Paris', ambiguous='infer')
# Out:
# 2018-12-28 11:45:00+01:00    4.4
# 2018-12-28 12:45:00+01:00    5.1
# 2018-12-28 13:45:00+01:00    6.1
# 2018-12-28 14:45:00+01:00    6.2
# 2018-12-28 15:45:00+01:00    6.1
# 2018-12-28 16:45:00+01:00    6.1
# 2018-12-28 17:45:00+01:00    5.7
# 2018-12-28 18:45:00+01:00    5.2
# 2018-12-28 19:45:00+01:00    4.7
# 2018-12-28 20:45:00+01:00    4.1
# 2018-12-28 21:45:00+01:00    3.9
# 2018-12-28 22:45:00+01:00    3.5
# dtype: float64

# %%
quarters = pd.period_range('2016Q1', periods=8, freq='Q')
quarters
# Out:
# PeriodIndex(['2016Q1', '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2',
#              '2017Q3', '2017Q4'],
#             dtype='period[Q-DEC]')

# %%
quarters + 3
# Out:
# PeriodIndex(['2016Q4', '2017Q1', '2017Q2', '2017Q3', '2017Q4', '2018Q1',
#              '2018Q2', '2018Q3'],
#             dtype='period[Q-DEC]')

# %%
quarters.asfreq('M')
# Out:
# PeriodIndex(['2016-03', '2016-06', '2016-09', '2016-12', '2017-03', '2017-06',
#              '2017-09', '2017-12'],
#             dtype='period[M]')

# %%
quarters.asfreq('M', how='start')
# Out:
# PeriodIndex(['2016-01', '2016-04', '2016-07', '2016-10', '2017-01', '2017-04',
#              '2017-07', '2017-10'],
#             dtype='period[M]')

# %%
quarters.asfreq('A')
# Out:
# PeriodIndex(['2016', '2016', '2016', '2016', '2017', '2017', '2017', '2017'], dtype='period[A-DEC]')

# %%
quarterly_revenue = pd.Series([300, 320, 290, 390, 320, 360, 310, 410], index=quarters)
quarterly_revenue
# Out:
# 2016Q1    300
# 2016Q2    320
# 2016Q3    290
# 2016Q4    390
# 2017Q1    320
# 2017Q2    360
# 2017Q3    310
# 2017Q4    410
# Freq: Q-DEC, dtype: int64

# %%
quarterly_revenue.plot(kind='line')
plt.show()

# %%
last_hours = quarterly_revenue.to_timestamp(how='end', freq='H')
last_hours
# Out:
# 2016-03-31 23:59:59.999999999    300
# 2016-06-30 23:59:59.999999999    320
# 2016-09-30 23:59:59.999999999    290
# 2016-12-31 23:59:59.999999999    390
# 2017-03-31 23:59:59.999999999    320
# 2017-06-30 23:59:59.999999999    360
# 2017-09-30 23:59:59.999999999    310
# 2017-12-31 23:59:59.999999999    410
# dtype: int64

# %%
last_hours.to_period()
# Out:
# 2016Q1    300
# 2016Q2    320
# 2016Q3    290
# 2016Q4    390
# 2017Q1    320
# 2017Q2    360
# 2017Q3    310
# 2017Q4    410
# Freq: Q-DEC, dtype: int64

# %%
months_2016 = pd.period_range('2016', periods=12, freq='M')
one_day_after_last_days = months_2016.asfreq('D') + 1
last_bdays = one_day_after_last_days.to_timestamp() - pd.tseries.offsets.BDay()
last_bdays.to_period('H') + 9
# Out:
# PeriodIndex(['2016-01-29 09:00', '2016-02-29 09:00', '2016-03-31 09:00',
#              '2016-04-29 09:00', '2016-05-31 09:00', '2016-06-30 09:00',
#              '2016-07-29 09:00', '2016-08-31 09:00', '2016-09-30 09:00',
#              '2016-10-31 09:00', '2016-11-30 09:00', '2016-12-30 09:00'],
#             dtype='period[H]')

# %%
people_dict = {
    'weight': pd.Series([68, 83, 112], index=['alice', 'bob', 'charles']),
    'birthyear': pd.Series([1984, 1985, 1992], index=['bob', 'alice', 'charles'], name='year'),
    'children': pd.Series([0,3], index=['charles', 'bob']),
    'hobby': pd.Series(['Biking', 'Dancing'], index=['alice', 'bob']),
}
people = pd.DataFrame(people_dict)
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %%
people['birthyear']
# Out:
# alice      1985
# bob        1984
# charles    1992
# Name: birthyear, dtype: int64

# %%
people[['birthyear', 'hobby']]
# Out:
#          birthyear    hobby
# alice         1985   Biking
# bob           1984  Dancing
# charles       1992      NaN

# %%
d2 = pd.DataFrame(
        people_dict,
        columns=['birthyear', 'weight', 'wight', 'height'],
        index=['bob', 'alice', 'eugene']
)
d2
# Out:
#         birthyear  weight wight height
# bob        1984.0    83.0   NaN    NaN
# alice      1985.0    68.0   NaN    NaN
# eugene        NaN     NaN   NaN    NaN

# %%
values = [
            [1985, np.nan, "Biking",   68],
            [1984, 3,      "Dancing",  83],
            [1992, 0,      np.nan,    112]
         ]
d3 = pd.DataFrame(
        values,
        columns=["birthyear", "children", "hobby", "weight"],
        index=["alice", "bob", "charles"]
     )
d3
# Out:
#          birthyear  children    hobby  weight
# alice         1985       NaN   Biking      68
# bob           1984       3.0  Dancing      83
# charles       1992       0.0      NaN     112

# %%
masked_array = np.ma.asarray(values, dtype=object)
masked_array[(0, 2), (1, 2)] = np.ma.masked
d3 = pd.DataFrame(
        masked_array,
        columns=['birthyear', 'children', 'hobby', 'weight'],
        index=['alice', 'bob', 'charles']
)
d3
# Out:
#         birthyear children    hobby weight
# alice        1985      NaN   Biking     68
# bob          1984        3  Dancing     83
# charles      1992        0      NaN    112

# %%
d4 = pd.DataFrame(
    d3,
    columns=['hobby', 'children'],
    index=['alcie', 'bob']
    )
d4
# Out:
#          hobby children
# alcie      NaN      NaN
# bob    Dancing        3

# %%
people = pd.DataFrame({
    'birthyear': {'alice': 1985, 'bob': 1984, 'charles': 1992},
    'hobby': {'alice': 'Biking', 'bob':'Dancing'},
    'weight': {'alice': 68, 'bob': 83, 'charles': 112},
    'children': {'bob': 3, 'charles': 0}
})
people
# Out:
#          birthyear    hobby  weight  children
# alice         1985   Biking      68       NaN
# bob           1984  Dancing      83       3.0
# charles       1992      NaN     112       0.0

# %%
d5 = pd.DataFrame(
  {
    ("public", "birthyear"):
        {("Paris","alice"): 1985, ("Paris","bob"): 1984, ("London","charles"): 1992},
    ("public", "hobby"):
        {("Paris","alice"): "Biking", ("Paris","bob"): "Dancing"},
    ("private", "weight"):
        {("Paris","alice"): 68, ("Paris","bob"): 83, ("London","charles"): 112},
    ("private", "children"):
        {("Paris", "alice"): np.nan, ("Paris","bob"): 3, ("London","charles"): 0}
  }
)
d5
# Out:
#                   public          private
#                birthyear    hobby  weight children
# Paris  alice        1985   Biking      68      NaN
#        bob          1984  Dancing      83      3.0
# London charles      1992      NaN     112      0.0

# %%
d5['public']
# Out:
#                 birthyear    hobby
# Paris  alice         1985   Biking
#        bob           1984  Dancing
# London charles       1992      NaN

# %%
d5['public']['hobby']
# Out:
# Paris   alice       Biking
#         bob        Dancing
# London  charles        NaN
# Name: hobby, dtype: object

# %%
d5
# Out:
#                   public          private
#                birthyear    hobby  weight children
# Paris  alice        1985   Biking      68      NaN
#        bob          1984  Dancing      83      3.0
# London charles      1992      NaN     112      0.0

# %%
d5.columns = d5.columns.droplevel(level = 0)
d5
# Out:
#                 birthyear    hobby  weight  children
# Paris  alice         1985   Biking      68       NaN
#        bob           1984  Dancing      83       3.0
# London charles       1992      NaN     112       0.0

# %%
d6 = d5.T
d6
# Out:
#             Paris           London
#             alice      bob charles
# birthyear    1985     1984    1992
# hobby      Biking  Dancing     NaN
# weight         68       83     112
# children      NaN      3.0     0.0

# %%
d7 = d6.stack()
d7
# Out:
#                   London    Paris
# birthyear alice      NaN     1985
#           bob        NaN     1984
#           charles   1992      NaN
# hobby     alice      NaN   Biking
#           bob        NaN  Dancing
# weight    alice      NaN       68
#           bob        NaN       83
#           charles    112      NaN
# children  bob        NaN      3.0
#           charles    0.0      NaN

# %%
d8 = d7.unstack()
d8
# Out:
#           London                Paris
#            alice  bob charles   alice      bob charles
# birthyear    NaN  NaN    1992    1985     1984     NaN
# children     NaN  NaN     0.0     NaN      3.0     NaN
# hobby        NaN  NaN     NaN  Biking  Dancing     NaN
# weight       NaN  NaN     112      68       83     NaN

# %%
d9 = d8.unstack()
d9
# Out:
# London  alice    birthyear        NaN
#                  children         NaN
#                  hobby            NaN
#                  weight           NaN
#         bob      birthyear        NaN
#                  children         NaN
#                  hobby            NaN
#                  weight           NaN
#         charles  birthyear       1992
#                  children         0.0
#                  hobby            NaN
#                  weight           112
# Paris   alice    birthyear       1985
#                  children         NaN
#                  hobby         Biking
#                  weight            68
#         bob      birthyear       1984
#                  children         3.0
#                  hobby        Dancing
#                  weight            83
#         charles  birthyear        NaN
#                  children         NaN
#                  hobby            NaN
#                  weight           NaN
# dtype: object

# %%
d10 = d9.unstack(level = (0,1))
d10
# Out:
#           London                Paris
#            alice  bob charles   alice      bob charles
# birthyear    NaN  NaN    1992    1985     1984     NaN
# children     NaN  NaN     0.0     NaN      3.0     NaN
# hobby        NaN  NaN     NaN  Biking  Dancing     NaN
# weight       NaN  NaN     112      68       83     NaN

# %%
people
# Out:
#          birthyear    hobby  weight  children
# alice         1985   Biking      68       NaN
# bob           1984  Dancing      83       3.0
# charles       1992      NaN     112       0.0

# %%
people.loc['charles']
# Out:
# birthyear    1992
# hobby         NaN
# weight        112
# children      0.0
# Name: charles, dtype: object

# %%
people.iloc[2]
# Out:
# birthyear    1992
# hobby         NaN
# weight        112
# children      0.0
# Name: charles, dtype: object

# %%
people.iloc[1:3]
# Out:
#          birthyear    hobby  weight  children
# bob           1984  Dancing      83       3.0
# charles       1992      NaN     112       0.0

# %%
people[np.array([True, False, True])]
# Out:
#          birthyear   hobby  weight  children
# alice         1985  Biking      68       NaN
# charles       1992     NaN     112       0.0

# %%
people[people['birthyear'] < 1990]
# Out:
#        birthyear    hobby  weight  children
# alice       1985   Biking      68       NaN
# bob         1984  Dancing      83       3.0

# %%
people[people['birthyear'] > 1990]
# Out:
#          birthyear hobby  weight  children
# charles       1992   NaN     112       0.0

# %%
people
# Out:
#          birthyear    hobby  weight  children
# alice         1985   Biking      68       NaN
# bob           1984  Dancing      83       3.0
# charles       1992      NaN     112       0.0

# %%
people['age'] = 2018 - people['birthyear']
people['over 30'] = people['age'] > 30
birthyears = people.pop('birthyear')
del people['children']

people
# Out:
#            hobby  weight  age  over 30
# alice     Biking      68   33     True
# bob      Dancing      83   34     True
# charles      NaN     112   26    False

# %%
birthyears
# Out:
# alice      1985
# bob        1984
# charles    1992
# Name: birthyear, dtype: int64

# %%
people['pets'] = pd.Series({'bob' : 1, 'charles': 1, 'eugene': 1 })
people
# Out:
#            hobby  weight  age  over 30  pets
# alice     Biking      68   33     True   NaN
# bob      Dancing      83   34     True   1.0
# charles      NaN     112   26    False   1.0

# %% [markdown]
# :

# %%
people.insert(1, 'height', [172, 181, 185])
people
# Out:
#            hobby  height  weight  age  over 30  pets
# alice     Biking     172      68   33     True   NaN
# bob      Dancing     181      83   34     True   1.0
# charles      NaN     185     112   26    False   1.0

# %%
people.assign(
    body_mass_index = people['weight'] / (people['height'] / 100) ** 2,
    has_pets = people['pets'] > 0
    )
# Out:
#            hobby  height  weight  age  over 30  pets  body_mass_index  \
# alice     Biking     172      68   33     True   NaN        22.985398
# bob      Dancing     181      83   34     True   1.0        25.335002
# charles      NaN     185     112   26    False   1.0        32.724617
#
#          has_pets
# alice       False
# bob          True
# charles      True

# %%
try:
  people.assign(
      body_mass_index = people['weight'] / (people['height'] / 100) ** 2,
      overweight = people['body_mass_index'] > 25
  )
except KeyError as e:
  print('Key error:', e)
# Out:
# Key error: 'body_mass_index'

# %%
(people
     .assign(body_mass_index = lambda df: df["weight"] / (df["height"] / 100) ** 2)
     .assign(overweight = lambda df: df["body_mass_index"] > 25)
)
# Out:
#            hobby  height  weight  age  over 30  pets  body_mass_index  \
# alice     Biking     172      68   33     True   NaN        22.985398
# bob      Dancing     181      83   34     True   1.0        25.335002
# charles      NaN     185     112   26    False   1.0        32.724617
#
#          overweight
# alice         False
# bob            True
# charles        True

# %%
people.eval('weight / (height/100) ** 2 > 25')
# Out:
# alice      False
# bob         True
# charles     True
# dtype: bool

# %%
people.eval('body_mass_index = weight / (height/100) ** 2', inplace=True)
people
# Out:
#            hobby  height  weight  age  over 30  pets  body_mass_index
# alice     Biking     172      68   33     True   NaN        22.985398
# bob      Dancing     181      83   34     True   1.0        25.335002
# charles      NaN     185     112   26    False   1.0        32.724617

# %%
overweight_threshold = 30
people.eval("overweight = body_mass_index > @overweight_threshold", inplace=True)
people
# Out:
#            hobby  height  weight  age  over 30  pets  body_mass_index  \
# alice     Biking     172      68   33     True   NaN        22.985398
# bob      Dancing     181      83   34     True   1.0        25.335002
# charles      NaN     185     112   26    False   1.0        32.724617
#
#          overweight
# alice         False
# bob           False
# charles        True

# %%
people.query('age > 30 and pets == 0')
# Out:
# Empty DataFrame
# Columns: [hobby, height, weight, age, over 30, pets, body_mass_index, overweight]
# Index: []

# %%
people.sort_index(ascending=False)
# Out:
#            hobby  height  weight  age  over 30  pets  body_mass_index  \
# charles      NaN     185     112   26    False   1.0        32.724617
# bob      Dancing     181      83   34     True   1.0        25.335002
# alice     Biking     172      68   33     True   NaN        22.985398
#
#          overweight
# charles        True
# bob           False
# alice         False

# %%
people.sort_index(axis=1, inplace=True)

# %%
people.sort_values(by='age', inplace=True)

# %%
people.sort_values(by='body_mass_index', inplace=True)
people.plot(kind='line', x='body_mass_index', y=['height', 'weight'])
plt.show()

# %%
people.plot(kind='scatter', x='height', y='weight', s=[40, 120, 200])
plt.show()

# %%
grades_array = np.array([[8, 8, 9], [10, 9, 9], [4, 8, 2], [9, 10, 10]])
grades = pd.DataFrame(grades_array, columns=["sep", "oct", "nov"], index=["alice", "bob", "charles", "darwin"])
grades
# Out:
#          sep  oct  nov
# alice      8    8    9
# bob       10    9    9
# charles    4    8    2
# darwin     9   10   10

# %%
np.sqrt(grades)
# Out:
#               sep       oct       nov
# alice    2.828427  2.828427  3.000000
# bob      3.162278  3.000000  3.000000
# charles  2.000000  2.828427  1.414214
# darwin   3.000000  3.162278  3.162278

# %%
grades + 1
# Out:
#          sep  oct  nov
# alice      9    9   10
# bob       11   10   10
# charles    5    9    3
# darwin    10   11   11

# %%
grades >= 5
# Out:
#            sep   oct    nov
# alice     True  True   True
# bob       True  True   True
# charles  False  True  False
# darwin    True  True   True

# %%
grades.mean()
# Out:
# sep    7.75
# oct    8.75
# nov    7.50
# dtype: float64

# %%
(grades > 5).all()
# Out:
# sep    False
# oct     True
# nov    False
# dtype: bool

# %%
(grades > 5).all(axis=1)
# Out:
# alice       True
# bob         True
# charles    False
# darwin      True
# dtype: bool

# %%
(grades == 10).any(axis=1)
# Out:
# alice      False
# bob         True
# charles    False
# darwin      True
# dtype: bool

# %%
grades - grades.mean()
# Out:
#           sep   oct  nov
# alice    0.25 -0.75  1.5
# bob      2.25  0.25  1.5
# charles -3.75 -0.75 -5.5
# darwin   1.25  1.25  2.5

# %%
pd.DataFrame([[7.75, 8.75, 7.50]]*4, index=grades.index, columns=grades.columns)
# Out:
#           sep   oct  nov
# alice    7.75  8.75  7.5
# bob      7.75  8.75  7.5
# charles  7.75  8.75  7.5
# darwin   7.75  8.75  7.5

# %%
grades - grades.values.mean()
# Out:
#          sep  oct  nov
# alice    0.0  0.0  1.0
# bob      2.0  1.0  1.0
# charles -4.0  0.0 -6.0
# darwin   1.0  2.0  2.0

# %%
bonus_array = np.array([[0, np.nan, 2], [np.nan, 1, 0], [0, 1, 0], [3, 3, 0]])
bonus_points = pd.DataFrame(bonus_array, columns=["oct", "nov", "dec"], index=["bob", "colin", "darwin", "charles"])
bonus_points
# Out:
#          oct  nov  dec
# bob      0.0  NaN  2.0
# colin    NaN  1.0  0.0
# darwin   0.0  1.0  0.0
# charles  3.0  3.0  0.0

# %%
grades + bonus_points
# Out:
#          dec   nov   oct  sep
# alice    NaN   NaN   NaN  NaN
# bob      NaN   NaN   9.0  NaN
# charles  NaN   5.0  11.0  NaN
# colin    NaN   NaN   NaN  NaN
# darwin   NaN  11.0  10.0  NaN

# %%
(grades + bonus_points).fillna(0)
# Out:
#          dec   nov   oct  sep
# alice    0.0   0.0   0.0  0.0
# bob      0.0   0.0   9.0  0.0
# charles  0.0   5.0  11.0  0.0
# colin    0.0   0.0   0.0  0.0
# darwin   0.0  11.0  10.0  0.0

# %%
bonus_points
# Out:
#          oct  nov  dec
# bob      0.0  NaN  2.0
# colin    NaN  1.0  0.0
# darwin   0.0  1.0  0.0
# charles  3.0  3.0  0.0

# %%
bonus_points.interpolate(axis=1)
# Out:
#          oct  nov  dec
# bob      0.0  1.0  2.0
# colin    NaN  1.0  0.0
# darwin   0.0  1.0  0.0
# charles  3.0  3.0  0.0

# %%
better_bonus_points = bonus_points.copy()
better_bonus_points.insert(0, "sep", 0)
better_bonus_points.loc["alice"] = 0
better_bonus_points = better_bonus_points.interpolate(axis=1)
better_bonus_points
# Out:
#          sep  oct  nov  dec
# bob      0.0  0.0  1.0  2.0
# colin    0.0  0.5  1.0  0.0
# darwin   0.0  0.0  1.0  0.0
# charles  0.0  3.0  3.0  0.0
# alice    0.0  0.0  0.0  0.0

# %%
grades + better_bonus_points
# Out:
#          dec   nov   oct   sep
# alice    NaN   9.0   8.0   8.0
# bob      NaN  10.0   9.0  10.0
# charles  NaN   5.0  11.0   4.0
# colin    NaN   NaN   NaN   NaN
# darwin   NaN  11.0  10.0   9.0

# %%
grades['dec'] = np.nan
final_grades = grades + better_bonus_points
final_grades
# Out:
#           sep   oct   nov  dec
# alice     8.0   8.0   9.0  NaN
# bob      10.0   9.0  10.0  NaN
# charles   4.0  11.0   5.0  NaN
# colin     NaN   NaN   NaN  NaN
# darwin    9.0  10.0  11.0  NaN

# %%
final_grades_clean = final_grades.dropna(how='all')
final_grades_clean
# Out:
#           sep   oct   nov  dec
# alice     8.0   8.0   9.0  NaN
# bob      10.0   9.0  10.0  NaN
# charles   4.0  11.0   5.0  NaN
# darwin    9.0  10.0  11.0  NaN

# %%
final_gardes_clean = final_grades_clean.dropna(axis=1, how='all')
final_grades_clean
# Out:
#           sep   oct   nov  dec
# alice     8.0   8.0   9.0  NaN
# bob      10.0   9.0  10.0  NaN
# charles   4.0  11.0   5.0  NaN
# darwin    9.0  10.0  11.0  NaN

# %%
final_grades['hobby'] = ['Biking', 'Dancing', np.nan, 'Dancing', 'Biking']
final_grades
# Out:
#           sep   oct   nov  dec    hobby
# alice     8.0   8.0   9.0  NaN   Biking
# bob      10.0   9.0  10.0  NaN  Dancing
# charles   4.0  11.0   5.0  NaN      NaN
# colin     NaN   NaN   NaN  NaN  Dancing
# darwin    9.0  10.0  11.0  NaN   Biking

# %%
grouped_grades = final_grades.groupby('hobby')
grouped_grades

# %%
grouped_grades.mean()

# %%
bonus_points
# Out:
#          oct  nov  dec
# bob      0.0  NaN  2.0
# colin    NaN  1.0  0.0
# darwin   0.0  1.0  0.0
# charles  3.0  3.0  0.0

# %%
more_grades = final_grades_clean.stack().reset_index()
more_grades.columns = ['name', 'month', 'grade']
more_grades["bonus"] = [np.nan, np.nan, np.nan, 0, np.nan, 2, 3, 3, 0, 0, 1, 0]
more_grades
# Out:
#        name month  grade  bonus
# 0     alice   sep    8.0    NaN
# 1     alice   oct    8.0    NaN
# 2     alice   nov    9.0    NaN
# 3       bob   sep   10.0    0.0
# 4       bob   oct    9.0    NaN
# 5       bob   nov   10.0    2.0
# 6   charles   sep    4.0    3.0
# 7   charles   oct   11.0    3.0
# 8   charles   nov    5.0    0.0
# 9    darwin   sep    9.0    0.0
# 10   darwin   oct   10.0    1.0
# 11   darwin   nov   11.0    0.0

# %%
pd.pivot_table(more_grades, index='name')
# Out:
# <ipython-input-458-569c4f09d544>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(more_grades, index='name')
#             bonus      grade
# name
# alice         NaN   8.333333
# bob      1.000000   9.666667
# charles  2.000000   6.666667
# darwin   0.333333  10.000000

# %%
pd.pivot_table(more_grades, index="name", values=["grade", "bonus"], aggfunc=np.max)
# Out:
#          bonus  grade
# name
# alice      NaN    9.0
# bob        2.0   10.0
# charles    3.0   11.0
# darwin     1.0   11.0

# %%
pd.pivot_table(more_grades, index='name', values='grade', columns='month', margins=True)
# Out:
# month      nov   oct    sep        All
# name
# alice     9.00   8.0   8.00   8.333333
# bob      10.00   9.0  10.00   9.666667
# charles   5.00  11.0   4.00   6.666667
# darwin   11.00  10.0   9.00  10.000000
# All       8.75   9.5   7.75   8.666667

# %%
pd.pivot_table(more_grades, index=('name', 'month'), margins=True)
# Out:
#                bonus  grade
# name    month
# alice   nov      NaN   9.00
#         oct      NaN   8.00
#         sep      NaN   8.00
# bob     nov    2.000  10.00
#         oct      NaN   9.00
#         sep    0.000  10.00
# charles nov    0.000   5.00
#         oct    3.000  11.00
#         sep    3.000   4.00
# darwin  nov    0.000  11.00
#         oct    1.000  10.00
#         sep    0.000   9.00
# All            1.125   8.75

# %%
much_data = np.fromfunction(lambda x,y: (x+y*y)%17*11, (10000, 26))
large_df = pd.DataFrame(much_data, columns=list("ABCDEFGHIJKLMNOPQRSTUVWXYZ"))
large_df[large_df % 16 == 0] = np.nan
large_df.insert(3, 'some_text', 'Blabla')
large_df
# Out:
#          A     B     C some_text      D      E      F     G      H      I  \
# 0      NaN  11.0  44.0    Blabla   99.0    NaN   88.0  22.0  165.0  143.0
# 1     11.0  22.0  55.0    Blabla  110.0    NaN   99.0  33.0    NaN  154.0
# 2     22.0  33.0  66.0    Blabla  121.0   11.0  110.0  44.0    NaN  165.0
# 3     33.0  44.0  77.0    Blabla  132.0   22.0  121.0  55.0   11.0    NaN
# 4     44.0  55.0  88.0    Blabla  143.0   33.0  132.0  66.0   22.0    NaN
# ...    ...   ...   ...       ...    ...    ...    ...   ...    ...    ...
# 9995   NaN   NaN  33.0    Blabla   88.0  165.0   77.0  11.0  154.0  132.0
# 9996   NaN  11.0  44.0    Blabla   99.0    NaN   88.0  22.0  165.0  143.0
# 9997  11.0  22.0  55.0    Blabla  110.0    NaN   99.0  33.0    NaN  154.0
# 9998  22.0  33.0  66.0    Blabla  121.0   11.0  110.0  44.0    NaN  165.0
# 9999  33.0  44.0  77.0    Blabla  132.0   22.0  121.0  55.0   11.0    NaN
#
#       ...     Q     R     S     T      U      V      W     X      Y      Z
# 0     ...  11.0   NaN  11.0  44.0   99.0    NaN   88.0  22.0  165.0  143.0
# 1     ...  22.0  11.0  22.0  55.0  110.0    NaN   99.0  33.0    NaN  154.0
# 2     ...  33.0  22.0  33.0  66.0  121.0   11.0  110.0  44.0    NaN  165.0
# 3     ...  44.0  33.0  44.0  77.0  132.0   22.0  121.0  55.0   11.0    NaN
# 4     ...  55.0  44.0  55.0  88.0  143.0   33.0  132.0  66.0   22.0    NaN
# ...   ...   ...   ...   ...   ...    ...    ...    ...   ...    ...    ...
# 9995  ...   NaN   NaN   NaN  33.0   88.0  165.0   77.0  11.0  154.0  132.0
# 9996  ...  11.0   NaN  11.0  44.0   99.0    NaN   88.0  22.0  165.0  143.0
# 9997  ...  22.0  11.0  22.0  55.0  110.0    NaN   99.0  33.0    NaN  154.0
# 9998  ...  33.0  22.0  33.0  66.0  121.0   11.0  110.0  44.0    NaN  165.0
# 9999  ...  44.0  33.0  44.0  77.0  132.0   22.0  121.0  55.0   11.0    NaN
#
# [10000 rows x 27 columns]

# %%
large_df.head()
# Out:
#       A     B     C some_text      D     E      F     G      H      I  ...  \
# 0   NaN  11.0  44.0    Blabla   99.0   NaN   88.0  22.0  165.0  143.0  ...
# 1  11.0  22.0  55.0    Blabla  110.0   NaN   99.0  33.0    NaN  154.0  ...
# 2  22.0  33.0  66.0    Blabla  121.0  11.0  110.0  44.0    NaN  165.0  ...
# 3  33.0  44.0  77.0    Blabla  132.0  22.0  121.0  55.0   11.0    NaN  ...
# 4  44.0  55.0  88.0    Blabla  143.0  33.0  132.0  66.0   22.0    NaN  ...
#
#       Q     R     S     T      U     V      W     X      Y      Z
# 0  11.0   NaN  11.0  44.0   99.0   NaN   88.0  22.0  165.0  143.0
# 1  22.0  11.0  22.0  55.0  110.0   NaN   99.0  33.0    NaN  154.0
# 2  33.0  22.0  33.0  66.0  121.0  11.0  110.0  44.0    NaN  165.0
# 3  44.0  33.0  44.0  77.0  132.0  22.0  121.0  55.0   11.0    NaN
# 4  55.0  44.0  55.0  88.0  143.0  33.0  132.0  66.0   22.0    NaN
#
# [5 rows x 27 columns]

# %%
large_df.tail(n=2)
# Out:
#          A     B     C some_text      D     E      F     G     H      I  ...  \
# 9998  22.0  33.0  66.0    Blabla  121.0  11.0  110.0  44.0   NaN  165.0  ...
# 9999  33.0  44.0  77.0    Blabla  132.0  22.0  121.0  55.0  11.0    NaN  ...
#
#          Q     R     S     T      U     V      W     X     Y      Z
# 9998  33.0  22.0  33.0  66.0  121.0  11.0  110.0  44.0   NaN  165.0
# 9999  44.0  33.0  44.0  77.0  132.0  22.0  121.0  55.0  11.0    NaN
#
# [2 rows x 27 columns]

# %%
large_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 27 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   A          8823 non-null   float64
#  1   B          8824 non-null   float64
#  2   C          8824 non-null   float64
#  3   some_text  10000 non-null  object
#  4   D          8824 non-null   float64
#  5   E          8822 non-null   float64
#  6   F          8824 non-null   float64
#  7   G          8824 non-null   float64
#  8   H          8822 non-null   float64
#  9   I          8823 non-null   float64
#  10  J          8823 non-null   float64
#  11  K          8822 non-null   float64
#  12  L          8824 non-null   float64
#  13  M          8824 non-null   float64
#  14  N          8822 non-null   float64
#  15  O          8824 non-null   float64
#  16  P          8824 non-null   float64
#  17  Q          8824 non-null   float64
#  18  R          8823 non-null   float64
#  19  S          8824 non-null   float64
#  20  T          8824 non-null   float64
#  21  U          8824 non-null   float64
#  22  V          8822 non-null   float64
#  23  W          8824 non-null   float64
#  24  X          8824 non-null   float64
#  25  Y          8822 non-null   float64
#  26  Z          8823 non-null   float64
# dtypes: float64(26), object(1)
# memory usage: 2.1+ MB

# %%
large_df.describe()
# Out:
#                  A            B            C            D            E  \
# count  8823.000000  8824.000000  8824.000000  8824.000000  8822.000000
# mean     87.977559    87.972575    87.987534    88.012466    87.983791
# std      47.535911    47.535523    47.521679    47.521679    47.535001
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
#                  F            G            H            I            J  ...  \
# count  8824.000000  8824.000000  8822.000000  8823.000000  8823.000000  ...
# mean     88.007480    87.977561    88.000000    88.022441    88.022441  ...
# std      47.519371    47.529755    47.536879    47.535911    47.535911  ...
# min      11.000000    11.000000    11.000000    11.000000    11.000000  ...
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000  ...
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000  ...
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000  ...
# max     165.000000   165.000000   165.000000   165.000000   165.000000  ...
#
#                  Q            R            S            T            U  \
# count  8824.000000  8823.000000  8824.000000  8824.000000  8824.000000
# mean     87.972575    87.977559    87.972575    87.987534    88.012466
# std      47.535523    47.535911    47.535523    47.521679    47.521679
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
#                  V            W            X            Y            Z
# count  8822.000000  8824.000000  8824.000000  8822.000000  8823.000000
# mean     87.983791    88.007480    87.977561    88.000000    88.022441
# std      47.535001    47.519371    47.529755    47.536879    47.535911
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
# [8 rows x 26 columns]

# %%
my_df = pd.DataFrame(
    [['Biking', 68.5, 1985, np.nan], ['Dancing', 83.1, 1984, 3]],
    columns=['hobby', 'weight', 'birthyear', 'children'],
    index=['alice', 'bob']
)
my_df
# Out:
#          hobby  weight  birthyear  children
# alice   Biking    68.5       1985       NaN
# bob    Dancing    83.1       1984       3.0

# %%
my_df.to_csv('my_df.csv')
my_df.to_html('my_df.html')
my_df.to_json('my_df.json')

# %%
for filename in ('my_df.csv', 'my_def.html', 'my_df.json'):
  print('#', filename)
  with open(filename, "rt") as f:
    print(f.read())
    print()
# Out:
#   File "<ipython-input-470-2b4284701c54>", line 3
#     with open(filename, "rt") as f:
#     ^
# IndentationError: unexpected indent

# %%
try:
  my_df.to_excel('my_df.xlsx', sheet_name='People')
except ImportError as e:
  print(e)

# %%
my_df_loaded = pd.read_csv('my_df.csv', index_col=0)
my_df_loaded
# Out:
#          hobby  weight  birthyear  children
# alice   Biking    68.5       1985       NaN
# bob    Dancing    83.1       1984       3.0

# %%
us_cities = None
try:
  csv_url = "https://raw.githubusercontent.com/plotly/datasets/master/us-cities-top-1k.csv"
  us_cities = pd.read_csv(csv_url, index_col=0)
  us_cities = us_cities.head()
except IOError as e:
  print(e)
us_cities
# Out:
#                      State  Population        lat         lon
# City
# Marysville      Washington       63269  48.051764 -122.177082
# Perris          California       72326  33.782519 -117.228648
# Cleveland             Ohio      390113  41.499320  -81.694361
# Worcester    Massachusetts      182544  42.262593  -71.802293
# Columbia    South Carolina      133358  34.000710  -81.034814

# %%
city_loc = pd.DataFrame(
    [
        ['CA', 'San Francisco', 37.781334, -122.416728],
        ['NY', 'New York', 40.705649, -74.008344],
        ['FL', 'Miami', 25.791100, -80320733],
        ['OH', 'Cleveland', 41.473508, -81.739791],
        ['UT', 'Salt Lake City', 40.755851, -111.896657]
    ], columns=['state', 'city', 'lat', 'lng'])
city_loc
# Out:
#   state            city        lat           lng
# 0    CA   San Francisco  37.781334 -1.224167e+02
# 1    NY        New York  40.705649 -7.400834e+01
# 2    FL           Miami  25.791100 -8.032073e+07
# 3    OH       Cleveland  41.473508 -8.173979e+01
# 4    UT  Salt Lake City  40.755851 -1.118967e+02

# %%
city_pop = pd.DataFrame(
    [
        [808976, "San Francisco", "California"],
        [8363710, "New York", "New-York"],
        [413201, "Miami", "Florida"],
        [2242193, "Houston", "Texas"]
    ], index=[3,4,5,6], columns=["population", "city", "state"])
city_pop
# Out:
#    population           city       state
# 3      808976  San Francisco  California
# 4     8363710       New York    New-York
# 5      413201          Miami     Florida
# 6     2242193        Houston       Texas

# %%
pd.merge(left=city_loc, right=city_pop, on='city')
# Out:
#   state_x           city        lat           lng  population     state_y
# 0      CA  San Francisco  37.781334 -1.224167e+02      808976  California
# 1      NY       New York  40.705649 -7.400834e+01     8363710    New-York
# 2      FL          Miami  25.791100 -8.032073e+07      413201     Florida

# %%
all_cities = pd.merge(left=city_loc, right=city_pop, on='city', how='outer')
all_cities
# Out:
#   state_x            city        lat           lng  population     state_y
# 0      CA   San Francisco  37.781334 -1.224167e+02    808976.0  California
# 1      NY        New York  40.705649 -7.400834e+01   8363710.0    New-York
# 2      FL           Miami  25.791100 -8.032073e+07    413201.0     Florida
# 3      OH       Cleveland  41.473508 -8.173979e+01         NaN         NaN
# 4      UT  Salt Lake City  40.755851 -1.118967e+02         NaN         NaN
# 5     NaN         Houston        NaN           NaN   2242193.0       Texas

# %%
pd.merge(left=city_loc, right=city_pop, on='city', how='right')
# Out:
#   state_x           city        lat           lng  population     state_y
# 0      CA  San Francisco  37.781334 -1.224167e+02      808976  California
# 1      NY       New York  40.705649 -7.400834e+01     8363710    New-York
# 2      FL          Miami  25.791100 -8.032073e+07      413201     Florida
# 3     NaN        Houston        NaN           NaN     2242193       Texas

# %%
city_pop2 = city_pop.copy()
city_pop2.columns = ['population', 'name', 'state']
pd.merge(left=city_loc, right=city_pop2, left_on='city', right_on='name')
# Out:
#   state_x           city        lat           lng  population           name  \
# 0      CA  San Francisco  37.781334 -1.224167e+02      808976  San Francisco
# 1      NY       New York  40.705649 -7.400834e+01     8363710       New York
# 2      FL          Miami  25.791100 -8.032073e+07      413201          Miami
#
#       state_y
# 0  California
# 1    New-York
# 2     Florida

# %%
result_concat = pd.concat([city_loc, city_pop])
result_concat
# Out:
#         state            city        lat           lng  population
# 0          CA   San Francisco  37.781334 -1.224167e+02         NaN
# 1          NY        New York  40.705649 -7.400834e+01         NaN
# 2          FL           Miami  25.791100 -8.032073e+07         NaN
# 3          OH       Cleveland  41.473508 -8.173979e+01         NaN
# 4          UT  Salt Lake City  40.755851 -1.118967e+02         NaN
# 3  California   San Francisco        NaN           NaN    808976.0
# 4    New-York        New York        NaN           NaN   8363710.0
# 5     Florida           Miami        NaN           NaN    413201.0
# 6       Texas         Houston        NaN           NaN   2242193.0

# %%
result_concat.loc[3]
# Out:
#         state           city        lat        lng  population
# 3          OH      Cleveland  41.473508 -81.739791         NaN
# 3  California  San Francisco        NaN        NaN    808976.0

# %%
pd.concat([city_loc, city_pop], ignore_index=True)
# Out:
#         state            city        lat           lng  population
# 0          CA   San Francisco  37.781334 -1.224167e+02         NaN
# 1          NY        New York  40.705649 -7.400834e+01         NaN
# 2          FL           Miami  25.791100 -8.032073e+07         NaN
# 3          OH       Cleveland  41.473508 -8.173979e+01         NaN
# 4          UT  Salt Lake City  40.755851 -1.118967e+02         NaN
# 5  California   San Francisco        NaN           NaN    808976.0
# 6    New-York        New York        NaN           NaN   8363710.0
# 7     Florida           Miami        NaN           NaN    413201.0
# 8       Texas         Houston        NaN           NaN   2242193.0

# %%
pd.concat([city_loc, city_pop], join='inner')
# Out:
#         state            city
# 0          CA   San Francisco
# 1          NY        New York
# 2          FL           Miami
# 3          OH       Cleveland
# 4          UT  Salt Lake City
# 3  California   San Francisco
# 4    New-York        New York
# 5     Florida           Miami
# 6       Texas         Houston

# %%
pd.concat([city_loc, city_pop], axis=1)
# Out:
#   state            city        lat           lng  population           city  \
# 0    CA   San Francisco  37.781334 -1.224167e+02         NaN            NaN
# 1    NY        New York  40.705649 -7.400834e+01         NaN            NaN
# 2    FL           Miami  25.791100 -8.032073e+07         NaN            NaN
# 3    OH       Cleveland  41.473508 -8.173979e+01    808976.0  San Francisco
# 4    UT  Salt Lake City  40.755851 -1.118967e+02   8363710.0       New York
# 5   NaN             NaN        NaN           NaN    413201.0          Miami
# 6   NaN             NaN        NaN           NaN   2242193.0        Houston
#
#         state
# 0         NaN
# 1         NaN
# 2         NaN
# 3  California
# 4    New-York
# 5     Florida
# 6       Texas

# %%
pd.concat([city_loc.set_index('city'), city_pop.set_index('city')], axis=1)
# Out:
#                state        lat           lng  population       state
# city
# San Francisco     CA  37.781334 -1.224167e+02    808976.0  California
# New York          NY  40.705649 -7.400834e+01   8363710.0    New-York
# Miami             FL  25.791100 -8.032073e+07    413201.0     Florida
# Cleveland         OH  41.473508 -8.173979e+01         NaN         NaN
# Salt Lake City    UT  40.755851 -1.118967e+02         NaN         NaN
# Houston          NaN        NaN           NaN   2242193.0       Texas

# %%
city_eco = city_pop.copy()
city_eco['eco_code'] = [17, 17, 34, 20]
city_eco
# Out:
#    population           city       state  eco_code
# 3      808976  San Francisco  California        17
# 4     8363710       New York    New-York        17
# 5      413201          Miami     Florida        34
# 6     2242193        Houston       Texas        20

# %%
city_eco['economy'] = city_eco['eco_code'].astype('category')
city_eco['economy'].cat.categories
# Out:
# Int64Index([17, 20, 34], dtype='int64')

# %%
city_eco['economy'].cat.categories = ['Finance', 'Energy', 'Tourism']
city_eco
